# %% [markdown]
# # F1 Data Exploration

# %%
import fastf1

import pandas as pd
import numpy as np

# %%
sg_qualifying = fastf1.get_session(2024, "Singapore Grand Prix", "Q")
sg_qualifying.load()
# Out:
# core           INFO 	Loading data for Singapore Grand Prix - Qualifying [v3.4.0]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['4', '1', '44', '63', '81', '27', '14', '22', '16', '55', '23', '43', '11', '20', '31', '3', '18', '10', '77', '24']

# %%
sg_qualifying.results.head(10)
# Out:
#    DriverNumber BroadcastName Abbreviation        DriverId         TeamName  \
# 4             4      L NORRIS          NOR          norris          McLaren
# 1             1  M VERSTAPPEN          VER  max_verstappen  Red Bull Racing
# 44           44    L HAMILTON          HAM        hamilton         Mercedes
# 63           63     G RUSSELL          RUS         russell         Mercedes
# 81           81     O PIASTRI          PIA         piastri          McLaren
# 27           27  N HULKENBERG          HUL      hulkenberg     Haas F1 Team
# 14           14      F ALONSO          ALO          alonso     Aston Martin
# 22           22     Y TSUNODA          TSU         tsunoda               RB
# 16           16     C LECLERC          LEC         leclerc          Ferrari
# 55           55       C SAINZ          SAI           sainz          Ferrari
#
#    TeamColor        TeamId FirstName    LastName         FullName  ...  \
# 4     FF8000       mclaren     Lando      Norris     Lando Norris  ...
# 1     3671C6      red_bull       Max  Verstappen   Max Verstappen  ...
# 44    27F4D2      mercedes     Lewis    Hamilton   Lewis Hamilton  ...
# 63    27F4D2      mercedes    George     Russell   George Russell  ...
# 81    FF8000       mclaren     Oscar     Piastri    Oscar Piastri  ...
# 27    B6BABD          haas      Nico  Hulkenberg  Nico Hulkenberg  ...
# 14    229971  aston_martin  Fernando      Alonso  Fernando Alonso  ...
# 22    6692FF            rb      Yuki     Tsunoda     Yuki Tsunoda  ...
# 16    E80020       ferrari   Charles     Leclerc  Charles Leclerc  ...
# 55    E80020       ferrari    Carlos       Sainz     Carlos Sainz  ...
#
#    CountryCode Position  ClassifiedPosition GridPosition  \
# 4          GBR      1.0                              NaN
# 1          NED      2.0                              NaN
# 44         GBR      3.0                              NaN
# 63         GBR      4.0                              NaN
# 81         AUS      5.0                              NaN
# 27         GER      6.0                              NaN
# 14         ESP      7.0                              NaN
# 22         JPN      8.0                              NaN
# 16         MON      9.0                              NaN
# 55         ESP     10.0                              NaN
#
#                        Q1                     Q2                     Q3 Time  \
# 4  0 days 00:01:30.002000 0 days 00:01:30.007000 0 days 00:01:29.525000  NaT
# 1  0 days 00:01:30.157000 0 days 00:01:29.680000 0 days 00:01:29.728000  NaT
# 44 0 days 00:01:30.393000 0 days 00:01:29.929000 0 days 00:01:29.841000  NaT
# 63 0 days 00:01:30.811000 0 days 00:01:30.153000 0 days 00:01:29.867000  NaT
# 81 0 days 00:01:30.258000 0 days 00:01:29.640000 0 days 00:01:29.953000  NaT
# 27 0 days 00:01:30.724000 0 days 00:01:30.150000 0 days 00:01:30.115000  NaT
# 14 0 days 00:01:30.684000 0 days 00:01:30.450000 0 days 00:01:30.214000  NaT
# 22 0 days 00:01:30.710000 0 days 00:01:30.289000 0 days 00:01:30.354000  NaT
# 16 0 days 00:01:30.786000 0 days 00:01:29.747000                    NaT  NaT
# 55 0 days 00:01:30.670000 0 days 00:01:30.108000                    NaT  NaT
#
#    Status Points
# 4            NaN
# 1            NaN
# 44           NaN
# 63           NaN
# 81           NaN
# 27           NaN
# 14           NaN
# 22           NaN
# 16           NaN
# 55           NaN
#
# [10 rows x 21 columns]

# %%
import fastf1
from fastf1.ergast import Ergast

SEASON = 2024
ROUND = 18

# %%
def get_drivers_standings():
    ergast = Ergast()
    standings = ergast.get_driver_standings(season=SEASON, round=ROUND)
    return standings.content[0]

# %%
get_drivers_standings()
# Out:
#     position positionText  points  wins         driverId  driverNumber  \
# 0          1            1   331.0     7   max_verstappen            33
# 1          2            2   279.0     3           norris             4
# 2          3            3   245.0     2          leclerc            16
# 3          4            4   237.0     2          piastri            81
# 4          5            5   190.0     1            sainz            55
# 5          6            6   174.0     2         hamilton            44
# 6          7            7   155.0     1          russell            63
# 7          8            8   144.0     0            perez            11
# 8          9            9    62.0     0           alonso            14
# 9         10           10    24.0     0       hulkenberg            27
# 10        11           11    24.0     0           stroll            18
# 11        12           12    22.0     0          tsunoda            22
# 12        13           13    12.0     0            albon            23
# 13        14           14    12.0     0        ricciardo             3
# 14        15           15     8.0     0            gasly            10
# 15        16           16     7.0     0          bearman            38
# 16        17           17     6.0     0  kevin_magnussen            20
# 17        18           18     5.0     0             ocon            31
# 18        19           19     4.0     0        colapinto            43
# 19        20           20     0.0     0             zhou            24
# 20        21           21     0.0     0         sargeant             2
# 21        22           22     0.0     0           bottas            77
#
#    driverCode                                          driverUrl  givenName  \
# 0         VER        http://en.wikipedia.org/wiki/Max_Verstappen        Max
# 1         NOR          http://en.wikipedia.org/wiki/Lando_Norris      Lando
# 2         LEC       http://en.wikipedia.org/wiki/Charles_Leclerc    Charles
# 3         PIA         http://en.wikipedia.org/wiki/Oscar_Piastri      Oscar
# 4         SAI      http://en.wikipedia.org/wiki/Carlos_Sainz_Jr.     Carlos
# 5         HAM        http://en.wikipedia.org/wiki/Lewis_Hamilton      Lewis
# 6         RUS  http://en.wikipedia.org/wiki/George_Russell_(r...     George
# 7         PER     http://en.wikipedia.org/wiki/Sergio_P%C3%A9rez     Sergio
# 8         ALO       http://en.wikipedia.org/wiki/Fernando_Alonso   Fernando
# 9         HUL  http://en.wikipedia.org/wiki/Nico_H%C3%BClkenberg       Nico
# 10        STR          http://en.wikipedia.org/wiki/Lance_Stroll      Lance
# 11        TSU          http://en.wikipedia.org/wiki/Yuki_Tsunoda       Yuki
# 12        ALB       http://en.wikipedia.org/wiki/Alexander_Albon  Alexander
# 13        RIC      http://en.wikipedia.org/wiki/Daniel_Ricciardo     Daniel
# 14        GAS          http://en.wikipedia.org/wiki/Pierre_Gasly     Pierre
# 15        BEA        http://en.wikipedia.org/wiki/Oliver_Bearman     Oliver
# 16        MAG       http://en.wikipedia.org/wiki/Kevin_Magnussen      Kevin
# 17        OCO          http://en.wikipedia.org/wiki/Esteban_Ocon    Esteban
# 18        COL      http://en.wikipedia.org/wiki/Franco_Colapinto     Franco
# 19        ZHO           http://en.wikipedia.org/wiki/Zhou_Guanyu     Guanyu
# 20        SAR        http://en.wikipedia.org/wiki/Logan_Sargeant      Logan
# 21        BOT       http://en.wikipedia.org/wiki/Valtteri_Bottas   Valtteri
#
#     familyName dateOfBirth driverNationality   constructorIds  \
# 0   Verstappen  1997-09-30             Dutch       [red_bull]
# 1       Norris  1999-11-13           British        [mclaren]
# 2      Leclerc  1997-10-16        Monegasque        [ferrari]
# 3      Piastri  2001-04-06        Australian        [mclaren]
# 4        Sainz  1994-09-01           Spanish        [ferrari]
# 5     Hamilton  1985-01-07           British       [mercedes]
# 6      Russell  1998-02-15           British       [mercedes]
# 7        Pérez  1990-01-26           Mexican       [red_bull]
# 8       Alonso  1981-07-29           Spanish   [aston_martin]
# 9   Hülkenberg  1987-08-19            German           [haas]
# 10      Stroll  1998-10-29          Canadian   [aston_martin]
# 11     Tsunoda  2000-05-11          Japanese             [rb]
# 12       Albon  1996-03-23              Thai       [williams]
# 13   Ricciardo  1989-07-01        Australian             [rb]
# 14       Gasly  1996-02-07            French         [alpine]
# 15     Bearman  2005-05-08           British  [ferrari, haas]
# 16   Magnussen  1992-10-05            Danish           [haas]
# 17        Ocon  1996-09-17            French         [alpine]
# 18   Colapinto  2003-05-27      Argentinian        [williams]
# 19        Zhou  1999-05-30           Chinese         [sauber]
# 20    Sargeant  2000-12-31          American       [williams]
# 21      Bottas  1989-08-28           Finnish         [sauber]
#
#                                       constructorUrls  \
# 0      [http://en.wikipedia.org/wiki/Red_Bull_Racing]
# 1              [http://en.wikipedia.org/wiki/McLaren]
# 2     [http://en.wikipedia.org/wiki/Scuderia_Ferrari]
# 3              [http://en.wikipedia.org/wiki/McLaren]
# 4     [http://en.wikipedia.org/wiki/Scuderia_Ferrari]
# 5   [http://en.wikipedia.org/wiki/Mercedes-Benz_in...
# 6   [http://en.wikipedia.org/wiki/Mercedes-Benz_in...
# 7      [http://en.wikipedia.org/wiki/Red_Bull_Racing]
# 8   [http://en.wikipedia.org/wiki/Aston_Martin_in_...
# 9         [http://en.wikipedia.org/wiki/Haas_F1_Team]
# 10  [http://en.wikipedia.org/wiki/Aston_Martin_in_...
# 11  [http://en.wikipedia.org/wiki/RB_Formula_One_T...
# 12  [http://en.wikipedia.org/wiki/Williams_Grand_P...
# 13  [http://en.wikipedia.org/wiki/RB_Formula_One_T...
# 14      [http://en.wikipedia.org/wiki/Alpine_F1_Team]
# 15  [http://en.wikipedia.org/wiki/Scuderia_Ferrari...
# 16        [http://en.wikipedia.org/wiki/Haas_F1_Team]
# 17      [http://en.wikipedia.org/wiki/Alpine_F1_Team]
# 18  [http://en.wikipedia.org/wiki/Williams_Grand_P...
# 19   [http://en.wikipedia.org/wiki/Sauber_Motorsport]
# 20  [http://en.wikipedia.org/wiki/Williams_Grand_P...
# 21   [http://en.wikipedia.org/wiki/Sauber_Motorsport]
#
#            constructorNames constructorNationalities
# 0                [Red Bull]               [Austrian]
# 1                 [McLaren]                [British]
# 2                 [Ferrari]                [Italian]
# 3                 [McLaren]                [British]
# 4                 [Ferrari]                [Italian]
# 5                [Mercedes]                 [German]
# 6                [Mercedes]                 [German]
# 7                [Red Bull]               [Austrian]
# 8            [Aston Martin]                [British]
# 9            [Haas F1 Team]               [American]
# 10           [Aston Martin]                [British]
# 11             [RB F1 Team]                [Italian]
# 12               [Williams]                [British]
# 13             [RB F1 Team]                [Italian]
# 14         [Alpine F1 Team]                 [French]
# 15  [Ferrari, Haas F1 Team]      [Italian, American]
# 16           [Haas F1 Team]               [American]
# 17         [Alpine F1 Team]                 [French]
# 18               [Williams]                [British]
# 19                 [Sauber]                  [Swiss]
# 20               [Williams]                [British]
# 21                 [Sauber]                  [Swiss]

# %%
def calculate_max_points_for_remaining_season():
    POINTS_FOR_SPRINT = 8 + 25 + 1  # Winning the sprint, race and fastest lap
    POINTS_FOR_CONVENTIONAL = 25 + 1  # Winning the race and fastest lap

    events = fastf1.events.get_event_schedule(SEASON, backend='ergast')
    events = events[events['RoundNumber'] > ROUND]
    # Count how many sprints and conventional races are left
    sprint_events = len(events.loc[events["EventFormat"] == "sprint_shootout"])
    conventional_events = len(events.loc[events["EventFormat"] == "conventional"])

    # Calculate points for each
    sprint_points = sprint_events * POINTS_FOR_SPRINT
    conventional_points = conventional_events * POINTS_FOR_CONVENTIONAL

    return sprint_points + conventional_points

calculate_max_points_for_remaining_season()
# Out:
# 78

# %%
def calculate_who_can_win(driver_standings, max_points):
    LEADER_POINTS = int(driver_standings.loc[0]['points'])

    for i, _ in enumerate(driver_standings.iterrows()):
        driver = driver_standings.loc[i]
        driver_max_points = int(driver["points"]) + max_points
        can_win = 'No' if driver_max_points < LEADER_POINTS else 'Yes'

        print(f"{driver['position']}: {driver['givenName'] + ' ' + driver['familyName']}, "
              f"Current points: {driver['points']}, "
              f"Theoretical max points: {driver_max_points}, "
              f"Can win: {can_win}")

# %%
# Get the current drivers standings
driver_standings = get_drivers_standings()

# Get the maximum amount of points
points = calculate_max_points_for_remaining_season()

# Print which drivers can still win
calculate_who_can_win(driver_standings, points)
# Out:
# 1: Max Verstappen, Current points: 331.0, Theoretical max points: 409, Can win: Yes
# 2: Lando Norris, Current points: 279.0, Theoretical max points: 357, Can win: Yes
# 3: Charles Leclerc, Current points: 245.0, Theoretical max points: 323, Can win: No
# 4: Oscar Piastri, Current points: 237.0, Theoretical max points: 315, Can win: No
# 5: Carlos Sainz, Current points: 190.0, Theoretical max points: 268, Can win: No
# 6: Lewis Hamilton, Current points: 174.0, Theoretical max points: 252, Can win: No
# 7: George Russell, Current points: 155.0, Theoretical max points: 233, Can win: No
# 8: Sergio Pérez, Current points: 144.0, Theoretical max points: 222, Can win: No
# 9: Fernando Alonso, Current points: 62.0, Theoretical max points: 140, Can win: No
# 10: Nico Hülkenberg, Current points: 24.0, Theoretical max points: 102, Can win: No
# 11: Lance Stroll, Current points: 24.0, Theoretical max points: 102, Can win: No
# 12: Yuki Tsunoda, Current points: 22.0, Theoretical max points: 100, Can win: No
# 13: Alexander Albon, Current points: 12.0, Theoretical max points: 90, Can win: No
# 14: Daniel Ricciardo, Current points: 12.0, Theoretical max points: 90, Can win: No
# 15: Pierre Gasly, Current points: 8.0, Theoretical max points: 86, Can win: No
# 16: Oliver Bearman, Current points: 7.0, Theoretical max points: 85, Can win: No
# 17: Kevin Magnussen, Current points: 6.0, Theoretical max points: 84, Can win: No
# 18: Esteban Ocon, Current points: 5.0, Theoretical max points: 83, Can win: No
# 19: Franco Colapinto, Current points: 4.0, Theoretical max points: 82, Can win: No
# 20: Guanyu Zhou, Current points: 0.0, Theoretical max points: 78, Can win: No
# 21: Logan Sargeant, Current points: 0.0, Theoretical max points: 78, Can win: No
# 22: Valtteri Bottas, Current points: 0.0, Theoretical max points: 78, Can win: No

# %%
import matplotlib.pyplot as plt
import fastf1.plotting
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
fastf1.plotting.setup_mpl(mpl_timedelta_support=True, misc_mpl_mods=False,
                          color_scheme='fastf1')

# load a session and its telemetry data
session = fastf1.get_session(2024, 'Singapore Grand Prix', 'Q')
session.load()
# Out:
# core           INFO 	Loading data for Singapore Grand Prix - Qualifying [v3.4.0]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['4', '1', '44', '63', '81', '27', '14', '22', '16', '55', '23', '43', '11', '20', '31', '3', '18', '10', '77', '24']

# %%
fastest_lap = session.laps.pick_fastest()
car_data = fastest_lap.get_car_data().add_distance()

# %%
circuit_info = session.get_circuit_info()
# Out:
# core        WARNING 	Failed to preserve data type for column 'X' while merging telemetry.
# core        WARNING 	Failed to preserve data type for column 'Y' while merging telemetry.
# core        WARNING 	Failed to preserve data type for column 'Z' while merging telemetry.

# %%
team_color = fastf1.plotting.get_team_color(fastest_lap['Team'],
                                            session=session)

fig, ax = plt.subplots()
ax.plot(car_data['Distance'], car_data['Speed'],
        color=team_color, label=fastest_lap['Driver'])

# Draw vertical dotted lines at each corner that range from slightly below the
# minimum speed to slightly above the maximum speed.
v_min = car_data['Speed'].min()
v_max = car_data['Speed'].max()
ax.vlines(x=circuit_info.corners['Distance'], ymin=v_min-20, ymax=v_max+20,
          linestyles='dotted', colors='grey')

# Plot the corner number just below each vertical line.
# For corners that are very close together, the text may overlap. A more
# complicated approach would be necessary to reliably prevent this.
for _, corner in circuit_info.corners.iterrows():
    txt = f"{corner['Number']}{corner['Letter']}"
    ax.text(corner['Distance'], v_min-30, txt,
            va='center_baseline', ha='center', size='small')

ax.set_xlabel('Distance in m')
ax.set_ylabel('Speed in km/h')
ax.legend()

# Manually adjust the y-axis limits to include the corner numbers, because
# Matplotlib does not automatically account for text that was manually added.
ax.set_ylim([v_min - 40, v_max + 20])

plt.title("Singapore Grand Prix 2024 Qualifying", size=10)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import colormaps
from matplotlib.collections import LineCollection

import fastf1


session = fastf1.get_session(2024, 'Singapore Grand Prix', 'R')
session.load()

lap = session.laps.pick_fastest()
tel = lap.get_telemetry()
# Out:
# core           INFO 	Loading data for Singapore Grand Prix - Race [v3.4.0]
# req            INFO 	No cached data found for session_info. Loading data...
# _api           INFO 	Fetching session info data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for driver_info. Loading data...
# _api           INFO 	Fetching driver list...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for session_status_data. Loading data...
# _api           INFO 	Fetching session status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for lap_count. Loading data...
# _api           INFO 	Fetching lap count data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for track_status_data. Loading data...
# _api           INFO 	Fetching track status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for _extended_timing_data. Loading data...
# _api           INFO 	Fetching timing data...
# _api           INFO 	Parsing timing data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for timing_app_data. Loading data...
# _api           INFO 	Fetching timing app data...
# req            INFO 	Data has been written to cache!
# core           INFO 	Processing timing data...
# req            INFO 	No cached data found for car_data. Loading data...
# _api           INFO 	Fetching car data...
# _api           INFO 	Parsing car data...
# _api        WARNING 	Driver  2: Car data is incomplete!
# _api        WARNING 	Driver 40: Car data is incomplete!
# _api        WARNING 	Driver  3: Car data is incomplete!
# _api        WARNING 	Driver 18: Car data is incomplete!
# _api        WARNING 	Driver 43: Car data is incomplete!
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for position_data. Loading data...
# _api           INFO 	Fetching position data...
# _api           INFO 	Parsing position data...
# _api        WARNING 	Driver  2: Position data is incomplete!
# _api        WARNING 	Driver 40: Position data is incomplete!
# _api        WARNING 	Driver  3: Position data is incomplete!
# _api        WARNING 	Driver 18: Position data is incomplete!
# _api        WARNING 	Driver 43: Position data is incomplete!
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for weather_data. Loading data...
# _api           INFO 	Fetching weather data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for race_control_messages. Loading data...
# _api           INFO 	Fetching race control messages...
# req            INFO 	Data has been written to cache!
# core           INFO 	Finished loading data for 20 drivers: ['4', '1', '81', '63', '16', '44', '55', '14', '27', '11', '43', '22', '31', '18', '24', '77', '10', '3', '20', '23']

# %%
x = np.array(tel['X'].values)
y = np.array(tel['Y'].values)

points = np.array([x, y]).T.reshape(-1, 1, 2)
segments = np.concatenate([points[:-1], points[1:]], axis=1)
gear = tel['nGear'].to_numpy().astype(float)

# %%
cmap = colormaps['Paired']
lc_comp = LineCollection(segments, norm=plt.Normalize(1, cmap.N+1), cmap=cmap)
lc_comp.set_array(gear)
lc_comp.set_linewidth(4)

# %%
plt.gca().add_collection(lc_comp)
plt.axis('equal')
plt.tick_params(labelleft=False, left=False, labelbottom=False, bottom=False)

title = plt.suptitle(
    f"Fastest Lap Gear Shift Visualization\n"
    f"{lap['Driver']} - {session.event['EventName']} {session.event.year}"
)

cbar = plt.colorbar(mappable=lc_comp, label="Gear",
                    boundaries=np.arange(1, 10))
cbar.set_ticks(np.arange(1.5, 9.5))
cbar.set_ticklabels(np.arange(1, 9))

plt.show()

# %%
plt.gca().add_collection(lc_comp)
plt.axis('equal')
plt.tick_params(labelleft=False, left=False, labelbottom=False, bottom=False)

title = plt.suptitle(
    f"Fastest Lap Gear Shift Visualization\n"
    f"{lap['Driver']} - {session.event['EventName']} {session.event.year}"
)

cbar = plt.colorbar(mappable=lc_comp, label="Gear",
                    boundaries=np.arange(1, 10))
cbar.set_ticks(np.arange(1.5, 9.5))
cbar.set_ticklabels(np.arange(1, 9))

plt.show()
